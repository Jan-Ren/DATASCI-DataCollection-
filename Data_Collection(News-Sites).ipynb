# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='77db759116714a8ab57e8912f2a36ac8')
# /v2/everything
all_articles = newsapi.get_everything(sources='bbc-news',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param='2021-03-11',
                                      to='2021-03-12',
                                      language='en',
                                      sort_by='relevancy')
all_articles
# Out:
# {'status': 'ok',
#  'totalResults': 565,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Mary Ann Azevedo',
#    'title': 'BlockFi lands a $350M Series D at a $3B valuation for its fast-growing crypto-lending platform',
#    'description': 'If there were any doubt about a cryptocurrency boom, we need look no further than at the explosion of growth of certain companies in the space. One such company is BlockFi, which today announced it has closed on a massive $350 million Series D funding that va…',
#    'url': 'http://techcrunch.com/2021/03/11/blockfi-lands-a-350m-series-d-at-3b-valuation-for-its-fast-growing-crypto-lending-platform/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/03/BlockFi-Founders-Zac-Prince-and-Flori-Marquez.jpg?w=684',
#    'publishedAt': '2021-03-11T13:30:14Z',
#    'content': 'If there were any doubt about a cryptocurrency boom, we need look no further than at the explosion of growth of certain companies in the space.\r\nOne such company is BlockFi, which today announced it … [+6662 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "Oxford-AstraZeneca: Denmark suspends vaccine 'as a precaution'",
#    'description': 'The decision follows a death and reports of blood clots, but the health minister says no link is established.',
#    'url': 'https://www.bbc.co.uk/news/world-europe-56357760',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/15DEE/production/_117528598_den.jpg',
#    'publishedAt': '2021-03-11T11:32:43Z',
#    'content': "image captionDenmark's health authority says the hold on the rollout of the Oxford-AstraZeneca vaccine is temporary\r\nDenmark has temporarily halted use of the Oxford-AstraZeneca vaccine as a precauti… [+3146 chars]"},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "The Hebrides' wild swimming 'real-life' mermaid",
#    'description': 'Kate Macleod can be found swimming in seas and lochs around the Western Isles in summer - and winter.',
#    'url': 'https://www.bbc.co.uk/news/uk-scotland-highlands-islands-56359621',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/141D8/production/_117529328_mermaideight.jpg',
#    'publishedAt': '2021-03-11T11:46:30Z',
#    'content': "A wild swimmer has been exploring the Western Isles' coast in a custom-made mermaid tale.\r\nimage copyrightBBC Alba/MacTV\r\nimage captionKate MacLeod swimming using one of her custom-made mermaid tales… [+1743 chars]"},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Natasha Lomas',
#    'title': 'Spain agrees on labor reform that will recognize delivery platform riders as employees',
#    'description': 'Spain’s government has reached an agreement with trade unions and business associations over labor reforms that will see delivery platform couriers recognized as employees, it said today. Once such a law is passed, the development could have major ramificatio…',
#    'url': 'http://techcrunch.com/2021/03/11/spain-agrees-on-labor-reform-that-will-recognize-delivery-platform-riders-as-employees/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/03/IMG_3703.jpg?w=533',
#    'publishedAt': '2021-03-11T15:01:10Z',
#    'content': 'Spain’s government has reached an agreement with trade unions and business associations over labor reforms that will see delivery platform couriers recognized as employees, it said today.\r\nOnce such … [+6676 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Jonathan Shieber',
#    'title': 'Taiwanese reassurances that water shortages won’t hit chipmaking show climate change’s direct threat to tech',
#    'description': 'A weekend statement from the Taiwanese government over its ability to provide water to the nation’s chip manufacturers in the face of an unprecedented drought make it clear that climate change is a direct threat to the foundations of the tech industry. As rep…',
#    'url': 'http://techcrunch.com/2021/03/11/taiwanese-reassurances-that-water-shortages-wont-hit-chipmaking-show-climate-changes-direct-threat-to-tech/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/01/GettyImages-1136663877.jpg?w=600',
#    'publishedAt': '2021-03-11T15:04:52Z',
#    'content': 'A weekend statement from the Taiwanese government over its ability to provide water to the nation’s chip manufacturers in the face of an unprecedented drought make it clear that climate change is a d… [+3661 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "Teen Vogue editor Alexi McCammond apologises for 'anti-Asian' tweets",
#    'description': "Staff at the magazine had said editor Alexi McCammond's tweets threatened the outlet's values.",
#    'url': 'https://www.bbc.co.uk/news/world-us-canada-56359165',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/10E98/production/_117527296_gettyimages-1183816965.jpg',
#    'publishedAt': '2021-03-11T12:30:02Z',
#    'content': 'image copyrightGetty Images\r\nimage captionAlexi McCammond, 29, was hired by Teen Vogue last week\r\nThe newly-appointed editor of Teen Vogue has apologised for "racist and homophobic" tweets she wrote … [+2859 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Roblox: David Baszucki worth $4.6bn as shares soar',
#    'description': "First day's trading sees David Baszucki's firm now worth more than some of the biggest gaming firms.",
#    'url': 'https://www.bbc.co.uk/news/technology-56359211',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/E4D6/production/_117528585_davidbaszucki.jpg',
#    'publishedAt': '2021-03-11T12:44:45Z',
#    'content': 'image copyrightGetty Images\r\nimage captionDavid Baszucki will be celebrating after his stake in Roblox soared in value\r\nChief executive of Roblox David Baszucki may well be letting out the "Oof" soun… [+2762 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Jonathan Shieber',
#    'title': 'Who knew high-tech farming of high-priced Japanese strawberries could be worth $50 million to investors?',
#    'description': "With prices ranging from $15 to $50, the strawberries grown by the vertical farming startup Oishii aren't going to be found in just any grocery store...",
#    'url': 'https://techcrunch.com/2021/03/11/who-knew-high-tech-farming-of-high-priced-japanese-strawberries-could-be-worth-50-million-to-investors/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/zm59wTxySK69Xwd9fb02Pg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTIwMDA7aD05Mzk-/https://s.yimg.com/uu/api/res/1.2/ojhrwUI7iylLKW.xXMhdqw--~B/aD0xMzQ0O3c9Mjg2MjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/techcrunch_350/5dc428fae22d944a9210921fde8ef115',
#    'publishedAt': '2021-03-11T12:46:41Z',
#    'content': "With prices ranging from $15 to $50, the strawberries grown by the vertical farming startup Oishii aren't going to be found in just any grocery store.\r\nInstead, the nearly five year-old startup is ta… [+6313 chars]"},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': '2021/03/11 12:00 GMT',
#    'description': 'The latest five minute news bulletin from BBC World Service.',
#    'url': 'https://www.bbc.co.uk/programmes/w172x5pc0dlv8sw',
#    'urlToImage': 'https://ichef.bbci.co.uk/images/ic/1200x675/p060dh18.jpg',
#    'publishedAt': '2021-03-11T12:06:00Z',
#    'content': 'The latest five minute news bulletin from BBC World Service.'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Circle of Hope: Boarding school couple charged after TikTok abuse allegations',
#    'description': "The ex-owners of Circle of Hope Girls' Ranch face more than 100 charges after women speak out online.",
#    'url': 'https://www.bbc.co.uk/news/world-us-canada-56357828',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/B2FF/production/_117532854_collage.jpg',
#    'publishedAt': '2021-03-11T14:54:58Z',
#    'content': "image captionThe couple's estranged daughter has helped expose their alleged abuse of girls at their ranch\r\nThe owners of a shuttered religious boarding school in Missouri, USA, are facing dozens of … [+4660 chars]"},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Anthony Ha',
#    'title': 'Facebook is bringing ads to shorter videos and Stories',
#    'description': 'Facebook is expanding its monetization options for video creators.  Facebook App Monetization Director Yoav Arnstein wrote in a blog post that creators will ...',
#    'url': 'https://techcrunch.com/2021/03/11/facebook-is-bringing-ads-to-shorter-videos-and-stories/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/UBH16w0O6RLsfi_37D40Kw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTIwMDA7aD0xMzM1/https://s.yimg.com/uu/api/res/1.2/h6Vf_zmLJtT_UBDgT5yJKQ--~B/aD0yMDAzO3c9MzAwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/techcrunch_350/68017cf8ea7ea27e5298113b65439b2f',
#    'publishedAt': '2021-03-11T14:00:06Z',
#    'content': "Facebook is expanding its monetization options for video creators. For anyone watching videos posted by those creators, that probably means you'll see more ads.\r\nFacebook App Monetization Director Yo… [+3819 chars]"},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Mary Ann Azevedo',
#    'title': 'BlockFi lands a $350M Series D at a $3B valuation for its fast-growing crypto-lending platform',
#    'description': 'One such company is BlockFi, which today announced it has closed on a massive $350 million Series D funding that values it at $3 billion.  While this news in...',
#    'url': 'https://techcrunch.com/2021/03/11/blockfi-lands-a-350m-series-d-at-3b-valuation-for-its-fast-growing-crypto-lending-platform/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/OnP80Q644UcWiuxrVXE2tg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTIwMDA7aD0xMTcw/https://s.yimg.com/uu/api/res/1.2/tjAjeqvDoT4q86aq6h42_A--~B/aD0yMDIxO3c9MzQ1NjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/techcrunch_350/7842e1d61da21092a49c8ba6ece3917f',
#    'publishedAt': '2021-03-11T13:30:14Z',
#    'content': 'If there were any doubt about a cryptocurrency boom, we need look no further than at the explosion of growth of certain companies in the space.\r\nOne such company is BlockFi, which today announced it … [+8622 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Darrell Etherington',
#    'title': 'Forward Health raises $225M from investors including The Weeknd as it looks to expand nationwide',
#    'description': 'Primary care startup Forward Health is looking to expand its tech-powered, personalized healthcare model across the U.S., and will use a new $225 million...',
#    'url': 'https://techcrunch.com/2021/03/11/forward-health-raises-225m-from-investors-including-the-weeknd-as-it-looks-to-expand-nationwide/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/xYwjopJLv1MJu_rqvFUaDg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTIwMDA7aD0xMzMz/https://s.yimg.com/uu/api/res/1.2/DlsPuqrU32WIGCdXP16Brw--~B/aD0yMDAwO3c9MzAwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/techcrunch_350/948bf8df071a5829edaa0e5165ec3937',
#    'publishedAt': '2021-03-11T11:30:17Z',
#    'content': 'Primary care startup Forward Health is looking to expand its tech-powered, personalized healthcare model across the U.S., and will use a new $225 million Series D raise to help make it happen. The ne… [+8317 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Romain Dillet',
#    'title': 'Hugging Face raises $40 million for its natural language processing library',
#    'description': 'Hugging Face has raised a $40 million Series B funding round — Addition is leading the round. The company has been building an open source library for natural language processing (NLP) technologies. You can find the Transformers library on GitHub — it has 42,…',
#    'url': 'http://techcrunch.com/2021/03/11/hugging-face-raises-40-million-for-its-natural-language-processing-library/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/12/Hugging-Face.jpg?w=533',
#    'publishedAt': '2021-03-11T15:11:38Z',
#    'content': 'Hugging Face has raised a $40 million Series B funding round Addition is leading the round. The company has been building an open source library for natural language processing (NLP) technologies. Yo… [+2004 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Anthony Ha',
#    'title': 'Gamefam aims to be the first big gaming company built on Roblox',
#    'description': 'Roblox went public yesterday after seeing tremendous growth in 2020, and that’s not just good news for the company’s employees and investors — there are also startups like Gamefam hoping to take advantage of the platform’s success. Roblox has a whole ecosyste…',
#    'url': 'http://techcrunch.com/2021/03/11/gamefam/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/03/Hot-Wheels-2.jpg?w=710',
#    'publishedAt': '2021-03-11T15:12:57Z',
#    'content': 'Roblox went public yesterday after seeing tremendous growth in 2020, and that’s not just good news for the company’s employees and investors there are also startups like Gamefam hoping to take advant… [+3811 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Sven Badzak death: Man, 20, charged with murder',
#    'description': 'Aspiring lawyer Sven Badzak was chased and then attacked while he was out to buy food.',
#    'url': 'https://www.bbc.co.uk/news/uk-england-london-56361293',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/D347/production/_116878045_ffca2ac0-bbaa-45b6-91f9-38ceeab2fb62.jpg',
#    'publishedAt': '2021-03-11T11:53:45Z',
#    'content': 'image copyrightMetropolitan Police\r\nimage captionSven Badzak has been described by his mother as someone "who would never raise a hand unless he was going to lift you up"\r\nA man has been charged with… [+840 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "Rushanara Ali: 'End of distressing period' for MP after 'stream of abuse'",
#    'description': 'Labour\'s Rushanara Ali said she "lived in fear" during an 18-month barrage of abusive messages.',
#    'url': 'https://www.bbc.co.uk/news/uk-england-london-56361297',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/050C/production/_117529210_hi040857655.jpg',
#    'publishedAt': '2021-03-11T13:09:40Z',
#    'content': 'image copyright UK Parliament\r\nimage captionHussain Sha said he would "blow up Rushanara\'s office terrorist-style with petrol"\r\nA Labour MP exposed to a stream of harassment by a constituent is marki… [+1918 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'Miguel Cummins: Kent sign West Indies bowler for start of season',
#    'description': 'Kent sign West Indies fast bowler Miguel Cummins for the first eight matches of the County Championship campaign.',
#    'url': 'https://www.bbc.co.uk/sport/cricket/56362792',
#    'urlToImage': 'https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/0783/production/_117532910_miguelcummins.jpg',
#    'publishedAt': '2021-03-11T13:54:46Z',
#    'content': 'Miguel Cummins took first-innings figures of 5-62 for Middlesex when the north London club drew with Kent in the Bob Willis Trophy last August\r\nKent have signed West Indies fast bowler Miguel Cummins… [+476 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Matt Burns',
#    'title': 'Happening today: Attend TechCrunch’s free Miami meetup to hear how to raise money from Miami investors',
#    'description': 'In just a few hours, we’re going to (virtually) meet up in the Magic City, Miami. Since we first let you know about our new Spotlight series, we’ve gotten a ton of registrations and some amazing submissions for our pitch-off. The small event features three se…',
#    'url': 'http://techcrunch.com/2021/03/11/happening-today-attend-techcrunchs-free-miami-meetup-to-hear-how-to-raise-money-from-miami-investors/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/03/tc-city-spot-miami-featured.jpg?w=711',
#    'publishedAt': '2021-03-11T14:11:43Z',
#    'content': 'In just a few hours, were going to (virtually) meet up in the Magic City, Miami. Since we first let you know about our new Spotlight series, weve gotten a ton of registrations and some amazing submis… [+2148 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'India v England: Eoin Morgan says tourists are not prioritising T20',
#    'description': 'Captain Eoin Morgan says it is a "rarity" for England to be at full strength in their Twenty20 series against India.',
#    'url': 'https://www.bbc.co.uk/sport/cricket/56363459',
#    'urlToImage': 'https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/14E27/production/_117534558_eoinmorgan.jpg',
#    'publishedAt': '2021-03-11T14:16:26Z',
#    'content': 'England captain Eoin Morgan is set to play his 100th T20 international during the series against India\r\nCaptain Eoin Morgan says it is a "rarity" for England to be at full strength in their Twenty20 … [+2910 chars]'}]}

# %%
import json
with open('all_articles.json', 'w', encoding='utf-8') as f:
    json.dump(all_articles, f, ensure_ascii=False, indent=4)
